# %%
import pandas as pd
import re
import os

# %%
path = "raw/GSE124070_SraRunTable.txt"
df = pd.read_csv(path)

# %%
geo_id = os.path.split(path)[-1].split("_")[0]

# %%
df["geo_id"] = geo_id

# %%
df.columns
# Out:
# Index(['Run', 'Assay Type', 'AssemblyName', 'AvgSpotLen', 'Bases',
#        'BioProject', 'BioSample', 'Bytes', 'Center Name', 'chip_antibody',
#        'Consent', 'DATASTORE filetype', 'DATASTORE provider',
#        'DATASTORE region', 'Experiment', 'GEO_Accession (exp)', 'Instrument',
#        'LibraryLayout', 'LibrarySelection', 'LibrarySource', 'Organism',
#        'origin', 'Platform', 'ReleaseDate', 'Sample Name', 'source_name',
#        'SRA Study', 'tissue', 'geo_id'],
#       dtype='object')

# %%
df["origin"].value_counts()
# Out:
# lcSSc patient    9
# healthy donor    9
# dcSSc patient    8
# Name: origin, dtype: int64

# %%
df["is_sample"] = 1

# %%
df["is_healthy"] = df["origin"].apply(lambda x : 1 if x == "healthy donor" else 0)

# %%
df["condition"] = df["origin"].apply(lambda x : "healthy donor" if x == "healthy donor" else "systemic sclerosis donor")

# %%
# Input Information completely omitted in this dataset
# df["is_sample"] = df["chip_antibody"].apply(lambda x : 0 if re.search(r"input", x) else 1)

# %%
df.to_csv("GSE124070_metaTable.csv")

# %%
df
# Out:
#            Run Assay Type      AssemblyName  AvgSpotLen       Bases  \
# 0   SRR8351056   ChIP-Seq        GRCH37.P13          73  1118764738
# 1   SRR8351057   ChIP-Seq        GRCH37.P13          70   866995428
# 2   SRR8351059   ChIP-Seq        GRCH37.P13          74   944704491
# 3   SRR8351060   ChIP-Seq        GRCH37.P13          74  1267334875
# 4   SRR8351061   ChIP-Seq        GRCH37.P13          75  1676387658
# 5   SRR8351062   ChIP-Seq        GRCH37.P13          71   641752003
# 6   SRR8351063   ChIP-Seq        GRCH37.P13          70   566368706
# 7   SRR8351064   ChIP-Seq        GRCH37.P13          75  1540202352
# 8   SRR8351065   ChIP-Seq  GCF_000001405.25          75    82092218
# 9   SRR8351066   ChIP-Seq        GRCH37.P13          74  1028305123
# 10  SRR8351067   ChIP-Seq        GRCH37.P13          75  1074193520
# 11  SRR8351068   ChIP-Seq        GRCH37.P13          75  1616139799
# 12  SRR8351069   ChIP-Seq        GRCH37.P13          75  1147838446
# ...
